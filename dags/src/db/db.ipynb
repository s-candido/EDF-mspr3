# %%
# %pip install psycopg2-binary
# Out:
# Requirement already satisfied: psycopg2-binary in /home/c-enjalbert/miniconda3/lib/python3.12/site-packages (2.9.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2

# %%
# Set environment variables
HOST="localhost"
DB="postgres"
USER="postgres"
PASSWORD="postgres"
PORT=5441

# %%
def create_table(conn, table_name):

    # Creating a cursor object using the cursor() method meteo_all_cities
    curs = conn.cursor()

    # Create the table if it doesn't exist
    curs.execute(f'''CREATE TABLE IF NOT EXISTS {table_name} (
        db_id TEXT PRIMARY KEY,
        dt BIGINT NOT NULL,
        min_temp REAL,
        max_temp REAL,
        min_humidity INTEGER,
        max_humidity INTEGER,
        precipitation REAL,
        uv INTEGER,
        weather_icon TEXT,
        weather_desc TEXT,
        sunrise BIGINT,
        sunset BIGINT,
        latitude REAL,
        longitude REAL,
        city TEXT
    )''')
    conn.commit()
    return conn

# %%
conn = psycopg2.connect(database=DB, user=USER, password=PASSWORD, host=HOST, port=PORT)

# %%
table_name="test_table3"
create_table(conn, table_name)
# Out:
# <connection object at 0x7af834242700; dsn: 'user=postgres password=xxx dbname=postgres host=localhost port=5441', closed: 0>

# %%
conn.close()
